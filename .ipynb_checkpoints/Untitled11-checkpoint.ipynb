# %%
import pandas as pd #para ler, visualizar e printar infos do df
import matplotlib.pyplot as plt #para construir e customizar gráficos
import seaborn as sns #para visualizar uns gráficos
import numpy as np #numpy porque é sempre bom importar numpy né

# %%
df = pd.read_csv("fipe_2022.csv")

# %%
df.head()
# Out:
#    year_of_reference month_of_reference fipe_code authentication  brand  \
# 0               2022            January  038001-6     vwmrywl5qs  Acura
# 1               2022            January  038001-6     t9mt723qhz  Acura
# 2               2022            January  038001-6     tr5wv4z21g  Acura
# 3               2022            January  038001-6     s2xxsjz3mt  Acura
# 4               2022            January  038001-6     rtm9gj7zk8  Acura
#
#      model      fuel    gear  engine_size  year_model  avg_price_brl  \
# 0  NSX 3.0  Gasoline  manual          3.0        1995        43779.0
# 1  NSX 3.0  Gasoline  manual          3.0        1994        42244.0
# 2  NSX 3.0  Gasoline  manual          3.0        1993        40841.0
# 3  NSX 3.0  Gasoline  manual          3.0        1992        39028.0
# 4  NSX 3.0  Gasoline  manual          3.0        1991        35678.0
#
#    age_years
# 0         28
# 1         29
# 2         30
# 3         31
# 4         32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290275 entries, 0 to 290274
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   year_of_reference   290275 non-null  int64
#  1   month_of_reference  290275 non-null  object
#  2   fipe_code           290275 non-null  object
#  3   authentication      290275 non-null  object
#  4   brand               290275 non-null  object
#  5   model               290275 non-null  object
#  6   fuel                290275 non-null  object
#  7   gear                290275 non-null  object
#  8   engine_size         290275 non-null  float64
#  9   year_model          290275 non-null  int64
#  10  avg_price_brl       290275 non-null  float64
#  11  age_years           290275 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 26.6+ MB

# %%
df.describe()
# Out:
#        year_of_reference    engine_size     year_model  avg_price_brl  \
# count           290275.0  290275.000000  290275.000000   2.902750e+05
# mean              2022.0       2.266047    2008.896633   1.220872e+05
# std                  0.0       1.033109       9.263619   3.219139e+05
# min               2022.0       0.700000    1985.000000   1.831000e+03
# 25%               2022.0       1.600000    2001.000000   2.187500e+04
# 50%               2022.0       2.000000    2010.000000   4.683600e+04
# 75%               2022.0       2.800000    2016.000000   1.061650e+05
# max               2022.0       6.700000    2023.000000   8.600000e+06
#
#            age_years
# count  290275.000000
# mean       14.103367
# std         9.263619
# min         0.000000
# 25%         7.000000
# 50%        13.000000
# 75%        22.000000
# max        38.000000

# %%
df.drop_duplicates(keep = 'first', inplace=True)

# %%
# Remover hífen e converter para inteiro na mesma coluna
df['fipe_code'] = df['fipe_code'].apply(lambda valor: int(valor.replace("-", "")))

# %%
# Dicionário de mapeamento de meses para números
meses_para_numeros = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

# Substituir nomes dos meses por números inteiros
df['month_of_reference'] = df['month_of_reference'].map(meses_para_numeros)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290273 entries, 0 to 290274
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   year_of_reference   290273 non-null  int64
#  1   month_of_reference  290273 non-null  int64
#  2   fipe_code           290273 non-null  int64
#  3   authentication      290273 non-null  object
#  4   brand               290273 non-null  object
#  5   model               290273 non-null  object
#  6   fuel                290273 non-null  object
#  7   gear                290273 non-null  object
#  8   engine_size         290273 non-null  float64
#  9   year_model          290273 non-null  int64
#  10  avg_price_brl       290273 non-null  float64
#  11  age_years           290273 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 28.8+ MB

# %%
df.isnull().sum()
# Out:
# year_of_reference     0
# month_of_reference    0
# fipe_code             0
# authentication        0
# brand                 0
# model                 0
# fuel                  0
# gear                  0
# engine_size           0
# year_model            0
# avg_price_brl         0
# age_years             0
# dtype: int64

# %%
# Assuming you want to analyze the last 2 years
current_year = 2023
years_to_analyze = 2
start_year = current_year - years_to_analyze + 1

# Filter the data for the last 2 years
filtered_df = df[(df['year_of_reference'] >= start_year) & (df['year_of_reference'] <= current_year)]

# Group the data by year and month, calculating the mean price
price_trends = filtered_df.groupby(['year_of_reference', 'month_of_reference'])['avg_price_brl'].mean().reset_index()

# Create a line plot to visualize the price trends
plt.figure(figsize=(10, 6))
for year in range(start_year, current_year + 1):
    year_data = price_trends[price_trends['year_of_reference'] == year]
    plt.plot(year_data['month_of_reference'], year_data['avg_price_brl'], marker='o', label=f'Year {year}')

plt.title('Average Car Prices Over the Last 2 Years')
plt.xlabel('Month')
plt.ylabel('Average Price (BRL)')
plt.xticks(range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Agrupar dados por mês e calcular a média dos preços
monthly_avg_prices = df.groupby('month_of_reference')['avg_price_brl'].mean()

# Criar um gráfico de barras para visualizar as variações sazonais
plt.figure(figsize=(10, 6))
monthly_avg_prices.plot(kind='bar')
plt.title('Flutuações sazonais nos preços dos automóveis')
plt.xlabel('Mes')
plt.ylabel('Valor Medio (BRL)')
plt.xticks(rotation=0)
plt.show()

# %%
# Calcula a média de preços para cada marca e modelo
brand_model_avg_prices = df.groupby(['brand', 'model'])['avg_price_brl'].mean().reset_index()

# Ordena as médias de preços em ordem decrescente e pega as top 10
top_10_high_prices = brand_model_avg_prices.nlargest(10, 'avg_price_brl')

# Cria um gráfico de barras para visualizar as top 10 médias mais altas
plt.figure(figsize=(12, 8))
bars = plt.barh(top_10_high_prices['brand'] + ' ' + top_10_high_prices['model'], top_10_high_prices['avg_price_brl'], color='red')
plt.title('Top 10 Car Brands and Models with Highest Average Prices')
plt.xlabel('Average Price (BRL)')
plt.ylabel('Brand and Model')
plt.gca().invert_yaxis()  # Inverte o eixo y para ter o maior valor no topo

# Adiciona os valores médios dentro das barras
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f'{bar.get_width():.2f}',
             va='center', ha='center', color='black', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Calculate the average prices for each fuel type
fuel_avg_prices = df.groupby('fuel')['avg_price_brl'].mean().reset_index()

# Create a bar plot to compare average prices based on fuel types
plt.figure(figsize=(10, 6))
plt.bar(fuel_avg_prices['fuel'], fuel_avg_prices['avg_price_brl'], color='purple')
plt.title('Average Car Prices Based on Fuel Types')
plt.xlabel('Fuel Type')
plt.ylabel('Average Price (BRL)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
gear_avg_prices = df.groupby('gear')['avg_price_brl'].mean().reset_index()

# Create a grouped bar chart to examine gear preferences and their impact on prices
plt.figure(figsize=(10, 6))
bars1 = plt.bar(gear_avg_prices['gear'], gear_avg_prices['avg_price_brl'], color='blue')

plt.title('Gear Preferences and Average Car Prices')
plt.xlabel('Gear Type')
plt.ylabel('Average Price (BRL)')
plt.tight_layout()

# Add data labels to the bars
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 200, round(yval, 2), ha='center', color='black', fontsize=10)

plt.show()

# %%
# Split data into brand new and used cars
new_cars = df[df['year_model'] == df['year_of_reference']]
used_cars = df[df['year_model'] != df['year_of_reference']]

# Calculate the average prices for brand new and used cars
avg_price_new_cars = new_cars['avg_price_brl'].mean()
avg_price_used_cars = used_cars['avg_price_brl'].mean()

# Create a bar plot to compare average prices of brand new and used cars
plt.figure(figsize=(8, 6))
plt.bar(['Brand New', 'Used'], [avg_price_new_cars, avg_price_used_cars], color=['blue', 'orange'])
plt.title('Average Prices of Brand New vs. Used Cars')
plt.xlabel('Car Condition')
plt.ylabel('Average Price (BRL)')
plt.tight_layout()
plt.show()

# %%
# Filtrar dados para o ano de 2022
df_2022 = df[df['year_of_reference'] == 2022]

# Criar uma lista de marcas e modelos únicos
brands = df_2022['brand'].unique()
models = df_2022['model'].unique()

# Criar subplots para cada marca
fig, axes = plt.subplots(nrows=len(brands), ncols=1, figsize=(10, 6 * len(brands)))

for i, brand in enumerate(brands):
    brand_data = df_2022[df_2022['brand'] == brand]
    
    ax = axes[i] if len(brands) > 1 else axes
    ax.set_title(f'Price Trends for {brand} Models in 2022')
    ax.set_xlabel('Month')
    ax.set_ylabel('Average Price (BRL)')
    
    for model in models:
        model_data = brand_data[brand_data['model'] == model]
        ax.plot(model_data['month_of_reference'], model_data['avg_price_brl'], marker='o', label=model)
    
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21808\490113810.py in <module>
#      18
#      19     for model in models:
# ---> 20         model_data = brand_data[brand_data['model'] == model]
#      21         ax.plot(model_data['month_of_reference'], model_data['avg_price_brl'], marker='o', label=model)
#      22
#
# ~\anaconda3New\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3494         # Do we have a (boolean) 1d indexer?
#    3495         if com.is_bool_indexer(key):
# -> 3496             return self._getitem_bool_array(key)
#    3497
#    3498         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3New\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3548         # be reindexed to match DataFrame rows
#    3549         key = check_bool_indexer(self.index, key)
# -> 3550         indexer = key.nonzero()[0]
#    3551         return self._take_with_is_copy(indexer, axis=0)
#    3552
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000002C23CB898B0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3New\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# ~\anaconda3New\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3New\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3New\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3New\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3New\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3New\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3New\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3New\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# ~\anaconda3New\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~\anaconda3New\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3New\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2835
#    2836             self.patch.draw(renderer)
# -> 2837             mimage._draw_list_compositing_images(
#    2838                 renderer, self, artists, self.suppressComposite)
#    2839
#
# ~\anaconda3New\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\anaconda3New\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3New\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# ~\anaconda3New\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\anaconda3New\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3New\lib\site-packages\matplotlib\legend.py in draw(self, renderer)
#     618         # update the location and size of the legend. This needs to
#     619         # be done in any case to clip the figure right.
# --> 620         bbox = self._legend_box.get_window_extent(renderer)
#     621         self.legendPatch.set_bounds(bbox.x0, bbox.y0, bbox.width, bbox.height)
#     622         self.legendPatch.set_mutation_scale(fontsize)
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_window_extent(self, renderer)
#     348     def get_window_extent(self, renderer):
#     349         # docstring inherited
# --> 350         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     351         px, py = self.get_offset(w, h, xd, yd, renderer)
#     352         return mtransforms.Bbox.from_bounds(px - xd, py - yd, w, h)
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_extent_offsets(self, renderer)
#     434                     c.set_width(self.width)
#     435
# --> 436         whd_list = [c.get_extent(renderer)
#     437                     for c in self.get_visible_children()]
#     438         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in <listcomp>(.0)
#     434                     c.set_width(self.width)
#     435
# --> 436         whd_list = [c.get_extent(renderer)
#     437                     for c in self.get_visible_children()]
#     438         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_extent(self, renderer)
#     343     def get_extent(self, renderer):
#     344         """Return a tuple ``width, height, xdescent, ydescent`` of the box."""
# --> 345         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     346         return w, h, xd, yd
#     347
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_extent_offsets(self, renderer)
#     470         sep = self.sep * dpicor
#     471
# --> 472         whd_list = [c.get_extent(renderer)
#     473                     for c in self.get_visible_children()]
#     474
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in <listcomp>(.0)
#     470         sep = self.sep * dpicor
#     471
# --> 472         whd_list = [c.get_extent(renderer)
#     473                     for c in self.get_visible_children()]
#     474
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_extent(self, renderer)
#     343     def get_extent(self, renderer):
#     344         """Return a tuple ``width, height, xdescent, ydescent`` of the box."""
# --> 345         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     346         return w, h, xd, yd
#     347
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_extent_offsets(self, renderer)
#     434                     c.set_width(self.width)
#     435
# --> 436         whd_list = [c.get_extent(renderer)
#     437                     for c in self.get_visible_children()]
#     438         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in <listcomp>(.0)
#     434                     c.set_width(self.width)
#     435
# --> 436         whd_list = [c.get_extent(renderer)
#     437                     for c in self.get_visible_children()]
#     438         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_extent(self, renderer)
#     343     def get_extent(self, renderer):
#     344         """Return a tuple ``width, height, xdescent, ydescent`` of the box."""
# --> 345         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     346         return w, h, xd, yd
#     347
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_extent_offsets(self, renderer)
#     470         sep = self.sep * dpicor
#     471
# --> 472         whd_list = [c.get_extent(renderer)
#     473                     for c in self.get_visible_children()]
#     474
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in <listcomp>(.0)
#     470         sep = self.sep * dpicor
#     471
# --> 472         whd_list = [c.get_extent(renderer)
#     473                     for c in self.get_visible_children()]
#     474
#
# ~\anaconda3New\lib\site-packages\matplotlib\offsetbox.py in get_extent(self, renderer)
#     807
#     808     def get_extent(self, renderer):
# --> 809         _, h_, d_ = renderer.get_text_width_height_descent(
#     810             "lp", self._text._fontproperties,
#     811             ismath="TeX" if self._text.get_usetex() else False)
#
# ~\anaconda3New\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     268         flags = get_hinting_flag()
#     269         font = self._get_agg_font(prop)
# --> 270         font.set_text(s, 0.0, flags=flags)
#     271         w, h = font.get_width_height()  # width and height of unrotated string
#     272         d = font.get_descent()
#
# KeyboardInterrupt:
